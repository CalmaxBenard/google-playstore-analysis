# %% [markdown]
# # Import

# %%
import pandas as pd
import plotly.express as px
import numpy as np

# %% [markdown]
# ## Notebook Presentation

# %%
# Show numeric output in decimal format (2 dp)
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Data

# %%
df = pd.read_csv("apps.csv")

# %% [markdown]
# ## Cleaning Data

# %%
df.shape
# Out:
# (10841, 12)

# %%
df.sample(5)
# Out:
#                         App            Category  Rating  Reviews  Size_MBs  \
# 3371      Photo Editor 2018              BEAUTY    4.50      134     17.00
# 516               bm-Events              SOCIAL     NaN        0      8.10
# 7092        20 minutes (CH)  NEWS_AND_MAGAZINES    3.70     4379      6.30
# 8031         Ghost In Photo         PHOTOGRAPHY    3.90    28429     14.00
# 8641  Walk with Map My Walk  HEALTH_AND_FITNESS    4.50   144040     55.00
#
#        Installs  Type Price Content_Rating            Genres  \
# 3371     10,000  Free     0       Everyone            Beauty
# 516          10  Free     0           Teen            Social
# 7092  1,000,000  Free     0           Teen  News & Magazines
# 8031  5,000,000  Free     0           Teen       Photography
# 8641  5,000,000  Free     0       Everyone  Health & Fitness
#
#           Last_Updated         Android_Ver
# 3371     March 1, 2018        4.0.3 and up
# 516   November 1, 2016          4.4 and up
# 7092    August 3, 2018  Varies with device
# 8031    March 16, 2018          2.3 and up
# 8641     July 27, 2018          5.0 and up

# %% [markdown]
# ### Drop the Last_updated and android ver columns

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df = df.drop(["Last_Updated", "Android_Ver"], axis=1)

# %% [markdown]
# ### Missing Data

# %%
df.isna().values.sum()
# Out:
# 1475

# %%
df = df.dropna()

# %% [markdown]
# ### Duplicates

# %%
df.duplicated().sum()
# Out:
# 476

# %%
df_duplicates = df[df.duplicated()]

# %%
df_clean = df.drop_duplicates(subset=["App", "Type", "Price"])

# %%
df_clean.shape
# Out:
# (8199, 10)

# %% [markdown]
# ### Highest Rated App

# %%
df_clean = df_clean.reset_index()

# %%
df_clean = df_clean.drop("index", axis=1)

# %%
df_clean.head()
# Out:
#                                                App Category  Rating  Reviews  \
# 0                              KBA-EZ Health Guide  MEDICAL    5.00        4
# 1                                         Ra Ga Ba     GAME    5.00        2
# 2                                          Mu.F.O.     GAME    5.00        2
# 3                                 Brick Breaker BR     GAME    5.00        7
# 4  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00        1
#
#    Size_MBs Installs  Type  Price Content_Rating   Genres
# 0     25.00        1  Free      0       Everyone  Medical
# 1     20.00        1  Paid  $1.49       Everyone   Arcade
# 2     16.00        1  Paid  $0.99       Everyone   Arcade
# 3     19.00        5  Free      0       Everyone   Arcade
# 4      4.60        5  Free      0       Everyone  Medical

# %%
df_clean.sort_values("Rating", ascending=False).head(10)
# Out:
#                                                    App      Category  Rating  \
# 0                                  KBA-EZ Health Guide       MEDICAL    5.00
# 323                                       Sway Medical       MEDICAL    5.00
# 320                                  AJ Men's Grooming     LIFESTYLE    5.00
# 318                                     FK Dedinje BGD        SPORTS    5.00
# 317                                    CB VIDEO VISION   PHOTOGRAPHY    5.00
# 316                         Beacon Baptist Jupiter, FL     LIFESTYLE    5.00
# 315                                     BV Mobile Apps  PRODUCTIVITY    5.00
# 1311                               Florida Wildflowers        FAMILY    5.00
# 311                                       ADS-B Driver         TOOLS    5.00
# 1372  Superheroes, Marvel, DC, Comics, TV, Movies News        COMICS    5.00
#
#       Reviews  Size_MBs Installs  Type  Price Content_Rating        Genres
# 0           4     25.00        1  Free      0       Everyone       Medical
# 323         3     22.00      100  Free      0       Everyone       Medical
# 320         2     22.00      100  Free      0       Everyone     Lifestyle
# 318        36      2.60      100  Free      0       Everyone        Sports
# 317        13      2.60      100  Free      0       Everyone   Photography
# 316        14      2.60      100  Free      0       Everyone     Lifestyle
# 315         3      4.80      100  Free      0       Everyone  Productivity
# 1311        5     69.00    1,000  Free      0       Everyone     Education
# 311         2      6.30      100  Paid  $1.99       Everyone         Tools
# 1372       34     12.00    5,000  Free      0       Everyone        Comics

# %%
df_clean.sort_values("Size_MBs", ascending=False).head(10)
# Out:
#                                                    App            Category  \
# 7709                    Talking Babsy Baby: Baby Games           LIFESTYLE
# 8144                            Hungry Shark Evolution                GAME
# 7710                             Miami crime simulator                GAME
# 7711                      Gangster Town: Vice District              FAMILY
# 1718                                        Vi Trainer  HEALTH_AND_FITNESS
# 7712                                   Ultimate Tennis              SPORTS
# 6145                                         Post Bank             FINANCE
# 6146                       The Walking Dead: Our World                GAME
# 6147                     Stickman Legends: Shadow Wars                GAME
# 2690  Car Crash III Beam DH Real Damage Simulator 2018                GAME
#
#       Rating  Reviews  Size_MBs     Installs  Type  Price Content_Rating  \
# 7709    4.00   140995    100.00   10,000,000  Free      0       Everyone
# 8144    4.50  6074334    100.00  100,000,000  Free      0           Teen
# 7710    4.00   254518    100.00   10,000,000  Free      0     Mature 17+
# 7711    4.30    65146    100.00   10,000,000  Free      0     Mature 17+
# 1718    3.60      124    100.00        5,000  Free      0       Everyone
# 7712    4.30   183004    100.00   10,000,000  Free      0       Everyone
# 6145    4.50    60449    100.00    1,000,000  Free      0       Everyone
# 6146    4.00    22435    100.00    1,000,000  Free      0           Teen
# 6147    4.40    38419    100.00    1,000,000  Paid  $0.99   Everyone 10+
# 2690    3.60      151    100.00       10,000  Free      0       Everyone
#
#                       Genres
# 7709  Lifestyle;Pretend Play
# 8144                  Arcade
# 7710                  Action
# 7711              Simulation
# 1718        Health & Fitness
# 7712                  Sports
# 6145                 Finance
# 6146                  Action
# 6147                  Action
# 2690                  Racing

# %%
# Top 50 Apps with the highest reviews
df_clean.sort_values("Reviews", ascending=False).head(50)
# Out:
#                                                     App            Category  \
# 8187                                           Facebook              SOCIAL
# 8181                                 WhatsApp Messenger       COMMUNICATION
# 8188                                          Instagram              SOCIAL
# 8180           Messenger – Text and Video Chat for Free       COMMUNICATION
# 8130                                     Clash of Clans                GAME
# 8166            Clean Master- Space Cleaner & Antivirus               TOOLS
# 8198                                     Subway Surfers                GAME
# 8195                                            YouTube       VIDEO_PLAYERS
# 8167  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
# 8101                                       Clash Royale                GAME
# 8174                                   Candy Crush Saga                GAME
# 8175        UC Browser - Fast Download Private & Secure       COMMUNICATION
# 8129                     Racing
# 8150                     Action
# 7977                      Tools
# 8011                     Arcade
# 8178                     Action
# 8193                      Tools
# 7999              Communication
# 8155                      Tools
# 8009                     Action
# 8139                     Casual
# 8097                Photography
# 8035                Photography
# 8058            Personalization

# %% [markdown]
# ### Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_clean["Content_Rating"].value_counts()
ratings
# Out:
# Content_Rating
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
fig = px.pie(labels=ratings.index, values=ratings.values, title="Content Rating", names=ratings.index)
fig.update_traces(textposition="outside", textinfo="percent+label")
fig.show()
# Out:
# <div>                            <div id="d7a65097-f65e-46b2-a278-600cba81d0fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7a65097-f65e-46b2-a278-600cba81d0fa")) {                    Plotly.newPlot(                        "d7a65097-f65e-46b2-a278-600cba81d0fa",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Everyone","Teen","Mature 17+","Everyone 10+","Adults only 18+","Unrated"],"legendgroup":"","name":"","showlegend":true,"values":[6621,912,357,305,3,1],"type":"pie","textinfo":"percent+label","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outl ...
#
# var gd = document.

# %%
fig = px.pie(labels=ratings.index, values=ratings.values, title="Content Rating", names=ratings.index, hole=0.5)
fig.update_traces(textposition="inside", textinfo="percent")
fig.show()
# Out:
# <div>                            <div id="a5cd5120-d4e7-4eb7-b45a-5c839a4efbf2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5cd5120-d4e7-4eb7-b45a-5c839a4efbf2")) {                    Plotly.newPlot(                        "a5cd5120-d4e7-4eb7-b45a-5c839a4efbf2",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Everyone","Teen","Mature 17+","Everyone 10+","Adults only 18+","Unrated"],"legendgroup":"","name":"","showlegend":true,"values":[6621,912,357,305,3,1],"type":"pie","textinfo":"percent","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{" ...
#
# var gd = docum

# %% [markdown]
# ### Converting Data to Numeric Types

# %%
df_clean["Installs"].describe()
# Out:
# count          8199
# unique           19
# top       1,000,000
# freq           1417
# Name: Installs, dtype: object

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8199 entries, 0 to 8198
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   object
#  1   Category        8199 non-null   object
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   object
#  6   Type            8199 non-null   object
#  7   Price           8199 non-null   object
#  8   Content_Rating  8199 non-null   object
#  9   Genres          8199 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 640.7+ KB

# %%
# Convert installs column to numberic

# %%
df_clean["Installs"] = df_clean["Installs"].astype(str).str.replace(",","")

# %%
df_clean.Installs = pd.to_numeric(df_clean.Installs)

# %%
df_clean["Installs"].describe()
# Out:
# count           8,199.00
# mean        9,169,323.86
# std        58,249,330.53
# min                 1.00
# 25%            10,000.00
# 50%           100,000.00
# 75%         1,000,000.00
# max     1,000,000,000.00
# Name: Installs, dtype: float64

# %%
df_clean[["App", "Installs"]].groupby("Installs").count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        988
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %%
# Convert price column to numeric data

# %%
df_clean["Price"] = df_clean["Price"].astype(str).str.replace("$", "")

# %%
df_clean["Price"] = pd.to_numeric(df_clean["Price"])

# %%
df_clean.Price.describe()
# Out:
# count   8,199.00
# mean        1.04
# std        16.85
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max       400.00
# Name: Price, dtype: float64

# %%
df_clean[df_clean["Price"] > 250]
# Out:
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 370           most expensive app (H)     FAMILY    4.30        6      1.50
# 753   I am rich (Most expensive app)    FINANCE    4.10      129      2.70
# 944              I am extremely Rich  LIFESTYLE    2.90       41      2.90
# 1094                      I am Rich!    FINANCE    3.80       93     22.00
# 1143              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
# 1396                   I Am Rich Pro     FAMILY    4.40      201      2.70
# 1688                       I am Rich    FINANCE    4.30      180      3.80
# 1719              I am rich(premium)    FINANCE    3.50      472      0.94
# 1793                  I am Rich Plus     FAMILY    4.00      856      8.70
# 2101                      💎 I'm rich  LIFESTYLE    3.80      718     26.00
# 2387                   I am rich VIP  LIFESTYLE    3.80      411      2.60
# 2423                       I Am Rich     FAMILY    3.60      217      4.90
# 2466        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 3095               I Am Rich Premium    FINANCE    4.10     1867      4.70
# 4185                       I am rich  LIFESTYLE    3.80     3547      1.80
#
#       Installs  Type  Price Content_Rating         Genres
# 370        100  Paid 399.99       Everyone  Entertainment
# 753       1000  Paid 399.99           Teen        Finance
# 944       1000  Paid 379.99       Everyone      Lifestyle
# 1094      1000  Paid 399.99       Everyone        Finance
# 1143      1000  Paid 399.99       Everyone        Finance
# 1396      5000  Paid 399.99       Everyone  Entertainment
# 1688      5000  Paid 399.99       Everyone        Finance
# 1719      5000  Paid 399.99       Everyone        Finance
# 1793     10000  Paid 399.99       Everyone  Entertainment
# 2101     10000  Paid 399.99       Everyone      Lifestyle
# 2387     10000  Paid 299.99       Everyone      Lifestyle
# 2423     10000  Paid 389.99       Everyone  Entertainment
# 2466     10000  Paid 400.00       Everyone      Lifestyle
# 3095     50000  Paid 399.99       Everyone        Finance
# 4185    100000  Paid 399.99       Everyone      Lifestyle

# %%
# Drop apps with more than 250 price tag (mainly the I'm rich app)
df_clean = df_clean[df_clean["Price"] < 250]

# %%
df_clean.sort_values("Price", ascending=False).head()
# Out:
#                             App   Category  Rating  Reviews  Size_MBs  \
# 1012  Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
# 408                LTC AS Legal    MEDICAL    4.00        6      1.30
# 1267           I am Rich Person  LIFESTYLE    4.20      134      1.80
# 1158    A Manual of Acupuncture    MEDICAL    3.50      214     68.00
# 1145         PTA Content Master    MEDICAL    4.20       64     41.00
#
#       Installs  Type  Price Content_Rating     Genres
# 1012      1000  Paid  79.99       Everyone    Medical
# 408        100  Paid  39.99       Everyone    Medical
# 1267      1000  Paid  37.99       Everyone  Lifestyle
# 1158      1000  Paid  33.99       Everyone    Medical
# 1145      1000  Paid  29.99       Everyone    Medical

# %% [markdown]
# ## The Highest Growing App

# %%
def growth(installs, price):
    return installs * price

# %%
df_clean["Revenue-Estimates"] = np.vectorize(growth)(df_clean["Installs"], df_clean["Price"])

# %%
df_clean.sort_values("Revenue-Estimates", ascending=False)[:10]
# Out:
#                                 App     Category  Rating  Reviews  Size_MBs  \
# 7142                      Minecraft       FAMILY    4.50  2376564     19.00
# 6871                  Hitman Sniper         GAME    4.60   408292     29.00
# 5439  Grand Theft Auto: San Andreas         GAME    4.40   348962     26.00
# 5736            Facetune - For Free  PHOTOGRAPHY    4.40    49553     48.00
# 6194        Sleep as Android Unlock    LIFESTYLE    4.50    23966      0.85
# 4941            DraStic DS Emulator         GAME    4.60    87766     12.00
# 4472                   Weather Live      WEATHER    4.50    76593      4.75
# 6171                    Bloons TD 5       FAMILY    4.60   190086     94.00
# 5874        Five Nights at Freddy's         GAME    4.60   100805     50.00
# 5079     Card Wars - Adventure Time       FAMILY    4.30   129603     23.00
#
#       Installs  Type  Price Content_Rating                     Genres  \
# 7142  10000000  Paid   6.99   Everyone 10+  Arcade;Action & Adventure
# 6871  10000000  Paid   0.99     Mature 17+                     Action
# 5439   1000000  Paid   6.99     Mature 17+                     Action
# 5736   1000000  Paid   5.99       Everyone                Photography
# 6194   1000000  Paid   5.99       Everyone                  Lifestyle
# 4941   1000000  Paid   4.99       Everyone                     Action
# 4472    500000  Paid   5.99       Everyone                    Weather
# 6171   1000000  Paid   2.99       Everyone                   Strategy
# 5874   1000000  Paid   2.99           Teen                     Action
# 5079   1000000  Paid   2.99   Everyone 10+    Card;Action & Adventure
#
#       Revenue-Estimates
# 7142      69,900,000.00
# 6871       9,900,000.00
# 5439       6,990,000.00
# 5736       5,990,000.00
# 6194       5,990,000.00
# 4941       4,990,000.00
# 4472       2,995,000.00
# 6171       2,990,000.00
# 5874       2,990,000.00
# 5079       2,990,000.00

# %% [markdown]
# ### Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_clean.Category.nunique()
# Out:
# 33

# %%
# Top 10 Category
top = df_clean.Category.value_counts()[:10]
top
# Out:
# Category
# FAMILY             1606
# GAME                910
# TOOLS               719
# PRODUCTIVITY        301
# PERSONALIZATION     298
# LIFESTYLE           297
# FINANCE             296
# MEDICAL             292
# PHOTOGRAPHY         263
# BUSINESS            262
# Name: count, dtype: int64

# %%
px.bar(x=top.index, y=top.values)
# Out:
# <div>                            <div id="902c8bd1-8452-4e66-b0da-9abd5e645d94" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("902c8bd1-8452-4e66-b0da-9abd5e645d94")) {                    Plotly.newPlot(                        "902c8bd1-8452-4e66-b0da-9abd5e645d94",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["FAMILY","GAME","TOOLS","PRODUCTIVITY","PERSONALIZATION","LIFESTYLE","FINANCE","MEDICAL","PHOTOGRAPHY","BUSINESS"],"xaxis":"x","y":[1606,910,719,301,298,297,296,292,263,262],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar ...

# %%
cat_installs = df_clean.groupby("Category").agg({"Installs": pd.Series.sum})

# %%
cat_installs
# Out:
#                         Installs
# Category
# ART_AND_DESIGN         114233100
# AUTO_AND_VEHICLES       53129800
# BEAUTY                  26916200
# BOOKS_AND_REFERENCE   1665791655
# BUSINESS               692018120
# COMICS                  44931100
# COMMUNICATION        11039241530
# DATING                 140912410
# EDUCATION              352852000
# ENTERTAINMENT         2113660000
# EVENTS                  15949410
# FAMILY                4437554490
# FINANCE                455249400
# FOOD_AND_DRINK         211677750
# GAME                 13858762717
# HEALTH_AND_FITNESS    1134006220
# HOUSE_AND_HOME          97082000
# LIBRARIES_AND_DEMO      52083000
# LIFESTYLE              503611120
# MAPS_AND_NAVIGATION    503267560
# MEDICAL                 39162676
# NEWS_AND_MAGAZINES    2369110650
# PARENTING               31116110
# PERSONALIZATION       1532352930
# PHOTOGRAPHY           4649143130
# PRODUCTIVITY          5788070180
# SHOPPING              1400331540
# SOCIAL                5487841475
# SPORTS                1096431465
# TOOLS                 8099724500
# TRAVEL_AND_LOCAL      2894859300
# VIDEO_PLAYERS         3916897200
# WEATHER                361096500

# %%
cat_installs.sort_values("Installs", ascending=True, inplace=True)

# %%
bar = px.bar(x=cat_installs.Installs, 
       y=cat_installs.index, 
       orientation="h", 
       title="Category Popularity"       
      )
bar.update_layout(xaxis_title="Number of Downloads", yaxis_title="Category")
bar.show()
# Out:
# <div>                            <div id="7c59c4a2-4c41-4b0f-9633-dab7894d10dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c59c4a2-4c41-4b0f-9633-dab7894d10dd")) {                    Plotly.newPlot(                        "7c59c4a2-4c41-4b0f-9633-dab7894d10dd",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[15949410,26916200,31116110,39162676,44931100,52083000,53129800,97082000,114233100,140912410,211677750,352852000,361096500,455249400,503267560,503611120,692018120,1096431465,1134006220,1400331540,1532352930,1665791655,2113660000,2369110650,2894859300,3916897200,4437554490,4649143130,5487841475,5788070180,8099724500,11039241530,13858762717],"xaxis":"x","y":["EVENTS","BEAUTY","PARENTING","MEDICAL","COMICS","LIBRARIES_AND_DEMO","AUTO_AND_VEHICLES","HOUSE_AND_HOME","ART_AND_DESIGN","DATING","FOOD_AND_DRINK","EDUCATION","WEATHER","FINANCE","MAPS_AND_NAVIGATION","LIFESTYLE","BUSINESS","SPORTS","HEALTH_AND_FITNESS","SHOPPING","PERSONALIZATION","BOOKS_AND_REFERENCE","ENTERTAINMENT","NEWS_AND_MAGAZINES","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","FAMILY","PHOTOGRAPHY","SOCIAL","PRODUCTIVITY","TOOLS","COMMUNICATION","GAME"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a ...

# %% [markdown]
# ### Creating a Scatter plot

# %%
cat_number = df_clean.groupby("Category").agg({"App": pd.Series.count})

# %%
cat_number
# Out:
#                       App
# Category
# ART_AND_DESIGN         61
# AUTO_AND_VEHICLES      73
# BEAUTY                 42
# BOOKS_AND_REFERENCE   169
# BUSINESS              262
# COMICS                 54
# COMMUNICATION         257
# DATING                134
# EDUCATION             118
# ENTERTAINMENT         102
# EVENTS                 45
# FAMILY               1606
# FINANCE               296
# FOOD_AND_DRINK         94
# GAME                  910
# HEALTH_AND_FITNESS    243
# HOUSE_AND_HOME         62
# LIBRARIES_AND_DEMO     64
# LIFESTYLE             297
# MAPS_AND_NAVIGATION   118
# MEDICAL               292
# NEWS_AND_MAGAZINES    204
# PARENTING              50
# PERSONALIZATION       298
# PHOTOGRAPHY           263
# PRODUCTIVITY          301
# SHOPPING              180
# SOCIAL                203
# SPORTS                260
# TOOLS                 719
# TRAVEL_AND_LOCAL      187
# VIDEO_PLAYERS         148
# WEATHER                72

# %%
# Merge cat_number and cat_installs df

# %%
cat_df = pd.merge(cat_number, cat_installs, on="Category", how="inner")

# %%
cat_df.shape
# Out:
# (33, 2)

# %%
cat_df.head()
# Out:
#                      App    Installs
# Category
# ART_AND_DESIGN        61   114233100
# AUTO_AND_VEHICLES     73    53129800
# BEAUTY                42    26916200
# BOOKS_AND_REFERENCE  169  1665791655
# BUSINESS             262   692018120

# %%
cat_df.sort_values("Installs", ascending=False)
# Out:
#                       App     Installs
# Category
# GAME                  910  13858762717
# COMMUNICATION         257  11039241530
# TOOLS                 719   8099724500
# PRODUCTIVITY          301   5788070180
# SOCIAL                203   5487841475
# PHOTOGRAPHY           263   4649143130
# FAMILY               1606   4437554490
# VIDEO_PLAYERS         148   3916897200
# TRAVEL_AND_LOCAL      187   2894859300
# NEWS_AND_MAGAZINES    204   2369110650
# ENTERTAINMENT         102   2113660000
# BOOKS_AND_REFERENCE   169   1665791655
# PERSONALIZATION       298   1532352930
# SHOPPING              180   1400331540
# HEALTH_AND_FITNESS    243   1134006220
# SPORTS                260   1096431465
# BUSINESS              262    692018120
# LIFESTYLE             297    503611120
# MAPS_AND_NAVIGATION   118    503267560
# FINANCE               296    455249400
# WEATHER                72    361096500
# EDUCATION             118    352852000
# FOOD_AND_DRINK         94    211677750
# DATING                134    140912410
# ART_AND_DESIGN         61    114233100
# HOUSE_AND_HOME         62     97082000
# AUTO_AND_VEHICLES      73     53129800
# LIBRARIES_AND_DEMO     64     52083000
# COMICS                 54     44931100
# MEDICAL               292     39162676
# PARENTING              50     31116110
# BEAUTY                 42     26916200
# EVENTS                 45     15949410

# %%
scatter = px.scatter(cat_df,
                     x="App",
                     y="Installs",
                     title="Category Concentration",
                     size="App",
                     hover_name=cat_df.index,
                     color="Installs"
                    )
scatter.update_layout(xaxis_title="Number of Apps (Lower=More Concentration)",
                     yaxis_title="Installs",
                     yaxis=dict(type="log"))
scatter.show()
# Out:
# <div>                            <div id="50f12561-6d34-4cba-bddb-490bbfe4ab69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50f12561-6d34-4cba-bddb-490bbfe4ab69")) {                    Plotly.newPlot(                        "50f12561-6d34-4cba-bddb-490bbfe4ab69",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>App=%{marker.size}<br>Installs=%{marker.color}<extra></extra>","hovertext":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE","BUSINESS","COMICS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","HOUSE_AND_HOME","LIBRARIES_AND_DEMO","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"legendgroup":"","marker":{"color":[114233100,53129800,26916200,1665791655,692018120,44931100,11039241530,140912410,352852000,2113660000,15949410,4437554490,455249400,211677750,13858762717,1134006220,97082000,52083000,503611120,503267560,39162676,2369110650,31116110,1532352930,4649143130,5788070180,1400331540,5487841475,1096431465,8099724500,2894859300,3916897200,361096500],"coloraxis":"coloraxis","size":[61,73,42,169,262,54,257,134,118,102,45,1606,296,94,910,243,62,64,297,118,292,204,50,298,263,301,180,203,260,719,187,148,72],"sizemode":"area","sizeref":4.015,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[61,73,42,169,262,54,257,134,118,102,45,1606,296,94,910,243,62,64,297,118,292,204,50,298,263,301,180,203,260,719,187,148,72],"xaxis":"x","y":[114233100,53129800,26916200,1665791655,692018120,44931100,11039241530,140912410,352852000,2113660000,15949410,4437554490,455249400,211677750,13858762717,1134006220,97082000,52083000,503611120,503267560,39162676,2369110650,31116110,1532352930,4649143130,5788070180,1400331540,5487841475,1096431465,8099724500,2894859300,3916897200,361096500],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{ ...

# %% [markdown]
# ## Extracting Nested Column Data

# %%
# Determine the number of genres (has nested values)

# %%
df_clean.Genres.value_counts().sort_values()[:5]
# Out:
# Genres
# Lifestyle;Pretend Play      1
# Strategy;Education          1
# Adventure;Education         1
# Role Playing;Brain Games    1
# Tools;Education             1
# Name: count, dtype: int64

# %%
stack = df_clean.Genres.str.split(";", expand=True).stack()

# %%
stack.shape
# Out:
# (8564,)

# %%
num_genres = stack.value_counts()

# %%
len(num_genres)
# Out:
# 53

# %%
bar = px.bar(x=num_genres.index[:15],
            y=num_genres.values[:15],
            title="Top Genres",
            hover_name=num_genres.index[:15],
            color=num_genres.values[:15],
            color_continuous_scale="Agsunset")
bar.update_layout(xaxis_title="Genre",
                 yaxis_title="Number of Apps",
                 coloraxis_showscale=False)
bar.show()
# Out:
# <div>                            <div id="85d81187-7147-4458-9b5c-b7f9553bd12d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85d81187-7147-4458-9b5c-b7f9553bd12d")) {                    Plotly.newPlot(                        "85d81187-7147-4458-9b5c-b7f9553bd12d",                        [{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>x=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","hovertext":["Tools","Education","Entertainment","Action","Productivity","Personalization","Lifestyle","Finance","Medical","Sports","Photography","Business","Communication","Health & Fitness","Casual"],"legendgroup":"","marker":{"color":[719,587,498,304,301,298,298,296,292,270,263,262,258,245,216],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Tools","Education","Entertainment","Action","Productivity","Personalization","Lifestyle","Finance","Medical","Sports","Photography","Business","Communication","Health & Fitness","Casual"],"xaxis":"x","y":[719,587,498,304,301,298,298,296,292,270,263,262,258,245,216],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"par ...

# %% [markdown]
# ## Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_clean.Type.value_counts()
# Out:
# Type
# Free    7595
# Paid     589
# Name: count, dtype: int64

# %%
df_type = df_clean.groupby(["Category", "Type"], as_index=False).agg({"App": pd.Series.count})

# %%
df_type
# Out:
#              Category  Type  App
# 0      ART_AND_DESIGN  Free   58
# 1      ART_AND_DESIGN  Paid    3
# 2   AUTO_AND_VEHICLES  Free   72
# 3   AUTO_AND_VEHICLES  Paid    1
# 4              BEAUTY  Free   42
# ..                ...   ...  ...
# 56   TRAVEL_AND_LOCAL  Paid    8
# 57      VIDEO_PLAYERS  Free  144
# 58      VIDEO_PLAYERS  Paid    4
# 59            WEATHER  Free   65
# 60            WEATHER  Paid    7
#
# [61 rows x 3 columns]

# %%
bar = px.bar(df_type,
             x="Category",
             y="App",
             title="Free vs Paid Apps by Category",
             color="Type",
             barmode="group"
            )
bar.update_layout(xaxis_title="Category",
                  yaxis_title="Number of Apps",
                  xaxis={"categoryorder": "total descending"},
                  yaxis=dict(type="log")
                 )
bar.show()
# Out:
# <div>                            <div id="a9140682-3f29-48f8-9c8e-cfce173942bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9140682-3f29-48f8-9c8e-cfce173942bc")) {                    Plotly.newPlot(                        "a9140682-3f29-48f8-9c8e-cfce173942bc",                        [{"alignmentgroup":"True","hovertemplate":"Type=Free<br>Category=%{x}<br>App=%{y}<extra></extra>","legendgroup":"Free","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Free","offsetgroup":"Free","orientation":"v","showlegend":true,"textposition":"auto","x":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE","BUSINESS","COMICS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","HOUSE_AND_HOME","LIBRARIES_AND_DEMO","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"xaxis":"x","y":[58,72,42,161,253,54,235,131,114,100,45,1456,289,92,834,232,62,64,284,113,229,202,48,233,248,283,178,201,238,656,179,144,65],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type=Paid<br>Category=%{x}<br>App=%{y}<extra></extra>","legendgroup":"Paid","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Paid","offsetgroup":"Paid","orientation":"v","showlegend":true,"textposition":"auto","x":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BOOKS_AND_REFERENCE","BUSINESS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"xaxis":"x","y":[3,1,8,9,22,3,4,2,150,7,2,76,11,13,5,63,2,2,65,15,18,2,2,22,63,8,4,7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"# ...

# %% [markdown]
# ## Plotly Box Plots: Lost Downloads for Paid Apps

# %%
box = px.box(df_clean,
             y="Installs",
             x="Type",
             color="Type",
             notched=True,
             points="all",
             title="How Many Downloads are Paid Apps Giving Up?"
)
box.update_layout(yaxis=dict(type="log"))
box.show()
# Out:
# <div>                            <div id="9d3d6bf3-d3b2-4719-a546-389efaad67dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d3d6bf3-d3b2-4719-a546-389efaad67dd")) {                    Plotly.newPlot(                        "9d3d6bf3-d3b2-4719-a546-389efaad67dd",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Type=%{x}<br>Installs=%{y}<extra></extra>","legendgroup":"Free","marker":{"color":"#636efa"},"name":"Free","notched":true,"offsetgroup":"Free","orientation":"v","showlegend":true,"x":["Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free ...

# %% [markdown]
# ### Plotly Box Plots: Revenue by App Category

# %%
df_paid = df_clean[df_clean["Type"] == "Paid"]

# %%
box = px.box(df_paid,
             x="Category",
             y="Revenue-Estimates",
             title="How Much Can Paid Apps Earn?"
            )
box.update_layout(xaxis_title="Category",
                  yaxis_title="Paid App Ballpark Revenue",
                  xaxis={"categoryorder": "min ascending"},
                  yaxis=dict(type="log")
                 )
box.show()
# Out:
# <div>                            <div id="edc4965f-8203-4221-8a13-770b5b62ce2a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edc4965f-8203-4221-8a13-770b5b62ce2a")) {                    Plotly.newPlot(                        "edc4965f-8203-4221-8a13-770b5b62ce2a",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Revenue-Estimates=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["GAME","GAME","FAMILY","BUSINESS","LIFESTYLE","FAMILY","PERSONALIZATION","PHOTOGRAPHY","FAMILY","GAME","PRODUCTIVITY","PHOTOGRAPHY","FAMILY","TOOLS","TOOLS","PERSONALIZATION","FAMILY","FAMILY","FAMILY","FAMILY","GAME","TOOLS","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","TOOLS","FAMILY","FAMILY","BUSINESS","BOOKS_AND_REFERENCE","FAMILY","FAMILY","FAMILY","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","GAME","PERSONALIZATION","FAMILY","FINANCE","SHOPPING","DATING","PERSONALIZATION","GAME","FAMILY","PRODUCTIVITY","FAMILY","MEDICAL","SPORTS","MEDICAL","PRODUCTIVITY","BUSINESS","PARENTING","LIFESTYLE","FAMILY","TOOLS","MAPS_AND_NAVIGATION","COMMUNICATION","PERSONALIZATION","COMMUNICATION","FAMILY","PERSONALIZATION","FAMILY","FAMILY","FAMILY","TOOLS","FAMILY","SPORTS","FAMILY","MEDICAL","FAMILY","FAMILY","GAME","TOOLS","FAMILY","FAMILY","PERSONALIZATION","BOOKS_AND_REFERENCE","GAME","PERSONALIZATION","GAME","GAME","TOOLS","MEDICAL","TOOLS","TOOLS","PERSONALIZATION","GAME","COMMUNICATION","MEDICAL","SPORTS","PERSONALIZATION","COMMUNICATION","COMMUNICATION","PERSONALIZATION","TOOLS","PERSONALIZATION","PERSONALIZATION","PRODUCTIVITY","MEDICAL","FAMILY","TOOLS","TOOLS","BUSINESS","COMMUNICATION","FAMILY","PERSONALIZATION","PHOTOGRAPHY","MEDICAL","PERSONALIZATION","MEDICAL","COMMUNICATION","PRODUCTIVITY","BOOKS_AND_REFERENCE","TOOLS","WEATHER","FAMILY","FAMILY","MEDICAL","FAMILY","TOOLS","TOOLS","SPORTS","GAME","MEDICAL","PERSONALIZATION","PERSONALIZATION","NEWS_AND_MAGAZINES","COMMUNICATION","TOOLS","MEDICAL","FINANCE","FAMILY","PERSONALIZATION","PERSONALIZATION","MEDICAL","FAMILY","MEDICAL","MEDICAL","FAMILY","FAMILY","FAMILY","GAME","PERSONALIZATION","TOOLS","PERSONALIZATION","GAME","GAME","GAME","FAMILY","FAMILY","PRODUCTIVITY","COMMUNICATION","SPORTS","SPORTS","FAMILY","PERSONALIZATION","MEDICAL","SPORTS","COMMUNICATION","LIFESTYLE","FAMILY","MEDICAL","MEDICAL","TOOLS","PRODUCTIVITY","FINANCE","HEALTH_AND_FITNESS","MEDICAL","PHOTOGRAPHY","FAMILY","FAMILY","PHOTOGRAPHY","SPORTS","ART_AND_DESIGN","FAMILY","PERSONALIZATION","PRODUCTIVITY","HEALTH_AND_FITNESS","MEDICAL","TOOLS","PRODUCTIVITY","GAME","TOOLS","MEDICAL","LIFESTYLE","GAME","MEDICAL","TRAVEL_AND_LOCAL","BUSINESS","MEDICAL","COMMUNICATION","PERSONALIZATION","GAME","TRAVEL_AND_LOCAL","GAME","SPORTS","MEDICAL","FAMILY","MEDICAL","TOOLS","BOOKS_AND_REFERENCE","FAMILY","MEDICAL","MEDICAL","GAME","BUSINESS","TOOLS","FAMILY","MEDICAL","PERSONALIZATION","PHOTOGRAPHY","SPORTS","MAPS_AND_NAVIGATION","PERSONALIZATION","GAME","BOOKS_AND_REFERENCE","EDUCATION","FAMILY","FAMILY","SOCIAL","MEDICAL","TOOLS","SPORTS","FAMILY","FAMILY","TOOLS","WEATHER","VIDEO_PLAYERS","MEDICAL","TOOLS","GAME","PERSONALIZATION","MEDICAL","LIFESTYLE","MEDICAL","DATING","HEALTH_AND_FITNESS","MEDICAL","FAMILY","PRODUCTIVITY","EDUCATION","SPORTS","FAMILY","PERSONALIZATION","PERSONALIZATION","FAMILY","GAME","FINANCE","GAME","MEDICAL","FAMILY","MEDICAL","MEDICAL","TOOLS","TOOLS","TOOLS","TOOLS","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","FAMILY","GAME","FAMILY","FAMILY","MEDICAL","SPORTS","LIFESTYLE","FAMILY","FAMILY","TRAVEL_AND_LOCAL","PERSONALIZATION","BOOKS_AND_REFERENCE","FAMILY","MEDICAL","MEDICAL","MEDICAL","MEDICAL", ...

# %%
box = px.box(df_paid,
             x="Category",
             y="Price",
             title="Price per Category"
            )
box.update_layout(xaxis_title="Category",
                  yaxis_title="Paid App Price",
                  xaxis={"categoryorder": "max descending"},
                  yaxis=dict(type="log")
                 )
box.show()
# Out:
# <div>                            <div id="397fef86-e883-4a11-acce-da79e8d4a340" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("397fef86-e883-4a11-acce-da79e8d4a340")) {                    Plotly.newPlot(                        "397fef86-e883-4a11-acce-da79e8d4a340",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["GAME","GAME","FAMILY","BUSINESS","LIFESTYLE","FAMILY","PERSONALIZATION","PHOTOGRAPHY","FAMILY","GAME","PRODUCTIVITY","PHOTOGRAPHY","FAMILY","TOOLS","TOOLS","PERSONALIZATION","FAMILY","FAMILY","FAMILY","FAMILY","GAME","TOOLS","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","TOOLS","FAMILY","FAMILY","BUSINESS","BOOKS_AND_REFERENCE","FAMILY","FAMILY","FAMILY","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","GAME","PERSONALIZATION","FAMILY","FINANCE","SHOPPING","DATING","PERSONALIZATION","GAME","FAMILY","PRODUCTIVITY","FAMILY","MEDICAL","SPORTS","MEDICAL","PRODUCTIVITY","BUSINESS","PARENTING","LIFESTYLE","FAMILY","TOOLS","MAPS_AND_NAVIGATION","COMMUNICATION","PERSONALIZATION","COMMUNICATION","FAMILY","PERSONALIZATION","FAMILY","FAMILY","FAMILY","TOOLS","FAMILY","SPORT